# %% [markdown]
# <a href="https://colab.research.google.com/github/princeofsport39-oss/my-work-/blob/main/Adeyemi_first_time_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Student Performance Analyzer")
name=("Moruf Maleek Adeyemi")
type("Moruf Maleek Adeyemi")
age=25
print("age")
print("Guidance & Counselinh Education")
m=97
p=94
s=77
total=m+p+s
print("total")
a=1
b=1
c=1
t=3
print(t)
average=total/t
print(average)
highestscore=97
print(highestscore)
lowestscore=77
print(lowestscore)
passed=True
print(passed)
# Out:
# Student Performance Analyzer
# age
# Guidance & Counselinh Education
# total
# 3
# 89.33333333333333
# 97
# 77
# True
